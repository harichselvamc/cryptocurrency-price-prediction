# %% [markdown]
# # Cryptocurrency Price Prediction

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (0.2.28)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas>=1.3.0 in c:\users\haric\appdata\roaming\python\python310\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\haric\appdata\roaming\python\python310\site-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\haric\appdata\roaming\python\python310\site-packages (from yfinance) (2023.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: six>=1.9 in c:\users\haric\appdata\roaming\python\python310\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\haric\appdata\roaming\python\python310\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\haric\appdata\roaming\python\python310\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\haric\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\haric\appdata\local\programs\python\python310\lib\site-packages)
# DEPRECATION: pytorch-lightning 1.7.6 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=768)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)

# %%
print(data.head())
# Out:
#         Date          Open          High           Low         Close  \
# 0 2021-07-19  31800.011719  31885.859375  30563.734375  30817.832031
# 1 2021-07-20  30838.285156  31006.187500  29360.955078  29807.347656
# 2 2021-07-21  29796.285156  32752.326172  29526.183594  32110.693359
# 3 2021-07-22  32138.873047  32576.400391  31745.298828  32313.105469
# 4 2021-07-23  32305.958984  33581.550781  32057.892578  33581.550781
#
#       Adj Close       Volume
# 0  30817.832031  20434789545
# 1  29807.347656  23148267245
# 2  32110.693359  28203024559
# 3  32313.105469  19555230518
# 4  33581.550781  22552046192

# %%
print(data.tail())
# Out:
#           Date          Open          High           Low         Close  \
# 763 2023-08-21  26188.691406  26220.201172  25846.087891  26124.140625
# 764 2023-08-22  26130.748047  26135.507812  25520.728516  26031.656250
# 765 2023-08-23  26040.474609  26786.898438  25804.998047  26431.640625
# 766 2023-08-24  26431.519531  26554.910156  25914.925781  26162.373047
# 767 2023-08-25  26163.679688  26248.103516  25786.812500  26047.667969
#
#         Adj Close       Volume
# 763  26124.140625  13371557893
# 764  26031.656250  14503820706
# 765  26431.640625  16985265785
# 766  26162.373047  12871532023
# 767  26047.667969  12406045118

# %%
data.shape
# Out:
# (768, 7)

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "Bitcoin Price Analysis", 
                     xaxis_rangeslider_visible=False)
figure.show()

# %%
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))
# Out:
# Close        1.000000
# Adj Close    1.000000
# High         0.998246
# Low          0.998172
# Open         0.996034
# Volume       0.208937
# Date        -0.705324
# Name: Close, dtype: float64

# %%
pip install autots
# Out:
# Requirement already satisfied: autots in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\haric\appdata\roaming\python\python310\site-packages (from autots) (1.25.2)
# Requirement already satisfied: pandas>=0.25.0 in c:\users\haric\appdata\roaming\python\python310\site-packages (from autots) (2.0.3)
# Requirement already satisfied: statsmodels>=0.10.0 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from autots) (0.14.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from autots) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\haric\appdata\roaming\python\python310\site-packages (from pandas>=0.25.0->autots) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\haric\appdata\roaming\python\python310\site-packages (from pandas>=0.25.0->autots) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\haric\appdata\roaming\python\python310\site-packages (from pandas>=0.25.0->autots) (2023.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\haric\appdata\roaming\python\python310\site-packages (from scikit-learn>=0.20.0->autots) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->autots) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.20.0->autots) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from statsmodels>=0.10.0->autots) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\haric\appdata\local\programs\python\python310\lib\site-packages (from statsmodels>=0.10.0->autots) (23.1)
# Requirement already satisfied: six in c:\users\haric\appdata\roaming\python\python310\site-packages (from patsy>=0.5.2->statsmodels>=0.10.0->autots) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\haric\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\haric\appdata\local\programs\python\python310\lib\site-packages)
# DEPRECATION: pytorch-lightning 1.7.6 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from autots import AutoTS
model = AutoTS(forecast_length=30, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Data frequency is: D, used frequency is: D
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 24/24 [==============================] - 6s 5ms/step - loss: 0.4176
# Epoch 2/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4174
# Epoch 3/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4160
# Epoch 4/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4153
# Epoch 5/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4146
# Epoch 6/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4145
# Epoch 7/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4141
# Epoch 8/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4149
# Epoch 9/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4143
# Epoch 10/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4161
# Epoch 11/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4136
# Epoch 12/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4164
# Epoch 13/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4146
# Epoch 14/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4140
# Epoch 15/50
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4142
# Epoch 16/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4152
# Epoch 17/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4155
# Epoch 18/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4147
# Epoch 19/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4144
# Epoch 20/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4148
# Epoch 21/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4148
# Epoch 22/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4139
# Epoch 23/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4141
# Epoch 24/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4135
# Epoch 25/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4146
# Epoch 26/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4130
# Epoch 27/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4138
# Epoch 28/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4145
# Epoch 29/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4137
# Epoch 30/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4152
# Epoch 31/50
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4149
# Epoch 32/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4148
# Epoch 33/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4136
# Epoch 34/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4143
# Epoch 35/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4143
# Epoch 36/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4149
# Epoch 37/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4138
# Epoch 38/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4150
# Epoch 39/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4133
# Epoch 40/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4137
# Epoch 41/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4141
# Epoch 42/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4142
# Epoch 43/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4131
# Epoch 44/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4133
# Epoch 45/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4123
# Epoch 46/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4133
# Epoch 47/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4139
# Epoch 48/50
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4126
# Epoch 49/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4134
# Epoch 50/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4140
# 1/1 [==============================] - 1s 975ms/step
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model ETS in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLM in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GLS in generation 0 of 10
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 15 in generation 0: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 16 in generation 0: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 17 in generation 0: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 18 in generation 0: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 19 in generation 0: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model UnobservedComponents in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 30 in generation 0: VAR
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31 in generation 0: VAR
# Model Number: 32 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 32 in generation 0: VECM
# Model Number: 33 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 33 in generation 0: VECM
# Model Number: 34 with model WindowRegression in generation 0 of 10
# Model Number: 35 with model ConstantNaive in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 36 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 36 in generation 0: FBProphet
# Model Number: 37 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 37 in generation 0: GluonTS
# Model Number: 38 with model MultivariateRegression in generation 0 of 10
# Model Number: 39 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 39 in generation 0: MultivariateRegression
# Model Number: 40 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 40 in generation 0: DatepartRegression
# Model Number: 41 with model SeasonalNaive in generation 0 of 10
# Model Number: 42 with model DatepartRegression in generation 0 of 10
# Model Number: 43 with model UnobservedComponents in generation 0 of 10
# Model Number: 44 with model UnobservedComponents in generation 0 of 10
# Model Number: 45 with model ETS in generation 0 of 10
# Model Number: 46 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 46 in generation 0: VECM
# Model Number: 47 with model ARDL in generation 0 of 10
# Model Number: 48 with model MultivariateMotif in generation 0 of 10
# Model Number: 49 with model MultivariateMotif in generation 0 of 10
# Model Number: 50 with model UnivariateMotif in generation 0 of 10
# Model Number: 51 with model UnivariateMotif in generation 0 of 10
# Model Number: 52 with model SectionalMotif in generation 0 of 10
# Model Number: 53 with model SectionalMotif in generation 0 of 10
# Model Number: 54 with model MultivariateRegression in generation 0 of 10
# Model Number: 55 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 55 in generation 0: FBProphet
# Model Number: 56 with model SeasonalNaive in generation 0 of 10
# Model Number: 57 with model DatepartRegression in generation 0 of 10
# Model Number: 58 with model NVAR in generation 0 of 10
# Model Number: 59 with model Theta in generation 0 of 10
# Model Number: 60 with model UnivariateRegression in generation 0 of 10
# Model Number: 61 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 61 in generation 0: ARCH
# Model Number: 62 with model ConstantNaive in generation 0 of 10
# Model Number: 63 with model LastValueNaive in generation 0 of 10
# Model Number: 64 with model AverageValueNaive in generation 0 of 10
# Model Number: 65 with model GLS in generation 0 of 10
# Model Number: 66 with model SeasonalNaive in generation 0 of 10
# Model Number: 67 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 67 in generation 0: GLM
# Model Number: 68 with model ETS in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning:
#
# Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:1406: RuntimeWarning:
#
# invalid value encountered in log
# Model Number: 69 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 69 in generation 0: FBProphet
# Model Number: 70 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 70 in generation 0: GluonTS
# Model Number: 71 with model UnobservedComponents in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.710e+08, tolerance: 3.480e+04
# Model Number: 72 with model VAR in generation 0 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 72 in generation 0: VAR
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 73 in generation 0: VECM
# Model Number: 74 with model ARIMA in generation 0 of 10
# Model Number: 75 with model WindowRegression in generation 0 of 10
# Model Number: 76 with model DatepartRegression in generation 0 of 10
# Model Number: 77 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 77 in generation 0: UnivariateRegression
# Model Number: 78 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 78 in generation 0: MultivariateRegression
# Model Number: 79 with model UnivariateMotif in generation 0 of 10
# Model Number: 80 with model MultivariateMotif in generation 0 of 10
# Model Number: 81 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("Model returned NaN due to a preprocessing transformer {'fillna': 'rolling_mean', 'transformations': {'0': 'SeasonalDifference', '1': 'AlignLastValue', '2': 'AlignLastValue', '3': 'EWMAFilter'}, 'transformation_params': {'0': {'lag_1': 7, 'method': 'LastValue'}, '1': {'rows': 1, 'lag': 1, 'method': 'multiplicative', 'strength': 1.0, 'first_value_only': False}, '2': {'rows': 1, 'lag': 1, 'method': 'additive', 'strength': 1.0, 'first_value_only': False}, '3': {'span': 12}}}. fail_on_forecast_nan=True") in model 81 in generation 0: SectionalMotif
# Model Number: 82 with model NVAR in generation 0 of 10
# Model Number: 83 with model Theta in generation 0 of 10
# Model Number: 84 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 84 in generation 0: ARDL
# Model Number: 85 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 85 in generation 0: ARCH
# Model Number: 86 with model MetricMotif in generation 0 of 10
# Model Number: 87 with model AverageValueNaive in generation 0 of 10
# Model Number: 88 with model UnobservedComponents in generation 0 of 10
# Model Number: 89 with model AverageValueNaive in generation 0 of 10
# Model Number: 90 with model LastValueNaive in generation 0 of 10
# Model Number: 91 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 91 in generation 0: ARDL
# Model Number: 92 with model WindowRegression in generation 0 of 10
# Model Number: 93 with model ConstantNaive in generation 0 of 10
# Model Number: 94 with model SeasonalNaive in generation 0 of 10
# Model Number: 95 with model ARDL in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Model Number: 96 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 96 in generation 0: FBProphet
# Model Number: 97 with model ConstantNaive in generation 0 of 10
# Model Number: 98 with model ConstantNaive in generation 0 of 10
# Model Number: 99 with model UnobservedComponents in generation 0 of 10
# Model Number: 100 with model ConstantNaive in generation 0 of 10
# Model Number: 101 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 101 in generation 0: VAR
# Model Number: 102 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 103 with model Theta in generation 0 of 10
# Model Number: 104 with model DatepartRegression in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_regression.py:500: UserWarning:
#
# One or more samples have no neighbors within specified radius; predicting NaN.
# Template Eval Error: ValueError('Model DatepartRegression returned NaN for one or more series. fail_on_forecast_nan=True') in model 104 in generation 0: DatepartRegression
# Model Number: 105 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 105 in generation 0: GLM
# Model Number: 106 with model ARCH in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 106 in generation 0: ARCH
# Model Number: 107 with model AverageValueNaive in generation 0 of 10
# Model Number: 108 with model MetricMotif in generation 0 of 10
# Model Number: 109 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Template Eval Error: Exception('Transformer DifferencedTransformer failed on inverse') in model 109 in generation 0: ETS
# Model Number: 110 with model ETS in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 110 in generation 0: ETS
# Model Number: 111 with model SeasonalNaive in generation 0 of 10
# Model Number: 112 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 112 in generation 0: ARCH
# Model Number: 113 with model SectionalMotif in generation 0 of 10
# Model Number: 114 with model SeasonalNaive in generation 0 of 10
# Model Number: 115 with model UnivariateRegression in generation 0 of 10
# Model Number: 116 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 116 in generation 0: VAR
# Model Number: 117 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 117 in generation 0: GluonTS
# Model Number: 118 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 118 in generation 0: GLM
# Model Number: 119 with model MultivariateMotif in generation 0 of 10
# Model Number: 120 with model AverageValueNaive in generation 0 of 10
# Model Number: 121 with model ConstantNaive in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:1367: ValueWarning:
#
# Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:1406: RuntimeWarning:
#
# invalid value encountered in log
# Model Number: 122 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 122 in generation 0: ARCH
# Model Number: 123 with model GLS in generation 0 of 10
# Model Number: 124 with model LastValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer RegressionFilter failed on fit') in model 124 in generation 0: LastValueNaive
# Model Number: 125 with model UnobservedComponents in generation 0 of 10
# Model Number: 126 with model LastValueNaive in generation 0 of 10
# Model Number: 127 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Unknown Distance Metric: kulsinski') in model 127 in generation 0: SectionalMotif
# Model Number: 128 with model GLS in generation 0 of 10
# Model Number: 129 with model Theta in generation 0 of 10
# Model Number: 130 with model UnobservedComponents in generation 0 of 10
# Model Number: 131 with model WindowRegression in generation 0 of 10
# Model Number: 132 with model NVAR in generation 0 of 10
# Model Number: 133 with model SeasonalNaive in generation 0 of 10
# Model Number: 134 with model UnobservedComponents in generation 0 of 10
# Model Number: 135 with model GLS in generation 0 of 10
# Model Number: 136 with model MetricMotif in generation 0 of 10
# Model Number: 137 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 137 in generation 0: VAR
# Model Number: 138 with model WindowRegression in generation 0 of 10
# Epoch 1/50
# 90/90 [==============================] - 7s 19ms/step - loss: nan
# Epoch 2/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 3/50
# 90/90 [==============================] - 2s 25ms/step - loss: nan
# Epoch 4/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 5/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 6/50
# 90/90 [==============================] - 2s 25ms/step - loss: nan
# Epoch 7/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 8/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 9/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 10/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 11/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 12/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 13/50
# 90/90 [==============================] - 2s 23ms/step - loss: nan
# Epoch 14/50
# 90/90 [==============================] - 2s 23ms/step - loss: nan
# Epoch 15/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 16/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 17/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 18/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 19/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 20/50
# 90/90 [==============================] - 2s 25ms/step - loss: nan
# Epoch 21/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 22/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 23/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 24/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 25/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 26/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 27/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 28/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 29/50
# 90/90 [==============================] - 2s 23ms/step - loss: nan
# Epoch 30/50
# 90/90 [==============================] - 3s 29ms/step - loss: nan
# Epoch 31/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 32/50
# 90/90 [==============================] - 3s 34ms/step - loss: nan
# Epoch 33/50
# 90/90 [==============================] - 3s 29ms/step - loss: nan
# Epoch 34/50
# 90/90 [==============================] - 2s 19ms/step - loss: nan
# Epoch 35/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 36/50
# 90/90 [==============================] - 2s 23ms/step - loss: nan
# Epoch 37/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 38/50
# 90/90 [==============================] - 2s 23ms/step - loss: nan
# Epoch 39/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 40/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 41/50
# 90/90 [==============================] - 2s 21ms/step - loss: nan
# Epoch 42/50
# 90/90 [==============================] - 2s 26ms/step - loss: nan
# Epoch 43/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 44/50
# 90/90 [==============================] - 2s 25ms/step - loss: nan
# Epoch 45/50
# 90/90 [==============================] - 2s 22ms/step - loss: nan
# Epoch 46/50
# 90/90 [==============================] - 3s 30ms/step - loss: nan
# Epoch 47/50
# 90/90 [==============================] - 2s 26ms/step - loss: nan
# Epoch 48/50
# 90/90 [==============================] - 2s 24ms/step - loss: nan
# Epoch 49/50
# 90/90 [==============================] - 2s 20ms/step - loss: nan
# Epoch 50/50
# 90/90 [==============================] - 2s 21ms/step - loss: nan
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Model Number: 139 with model GLM in generation 0 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\links.py:198: RuntimeWarning:
#
# overflow encountered in exp
# Model Number: 140 with model NVAR in generation 0 of 10
# Model Number: 141 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 141 in generation 0: VAR
# Model Number: 142 with model DatepartRegression in generation 0 of 10
# Model Number: 143 with model GLS in generation 0 of 10
# Model Number: 144 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 144 in generation 0: DatepartRegression
# Model Number: 145 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 145 in generation 0: VAR
# Model Number: 146 with model Theta in generation 0 of 10
# Model Number: 147 with model ETS in generation 0 of 10
# Model Number: 148 with model ConstantNaive in generation 0 of 10
# Model Number: 149 with model ARDL in generation 0 of 10
# Model Number: 150 with model SectionalMotif in generation 0 of 10
# Model Number: 151 with model VAR in generation 0 of 10
# Model Number: 152 with model DatepartRegression in generation 0 of 10
# Model Number: 153 with model Theta in generation 0 of 10
# Model Number: 154 with model MetricMotif in generation 0 of 10
# Model Number: 155 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 155 in generation 0: DatepartRegression
# Model Number: 156 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 156 in generation 0: GLM
# Model Number: 157 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation is incompatible with AutoTS. The numpy version is sometimes the issue, try 1.23.1 {as of 06-2023}') in model 157 in generation 0: GluonTS
# Model Number: 158 with model DatepartRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer AlignLastValue failed on inverse') in model 158 in generation 0: DatepartRegression
# Model Number: 159 with model NVAR in generation 0 of 10
# Model Number: 160 with model GLS in generation 0 of 10
# Model Number: 161 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 161 in generation 0: SectionalMotif
# Model Number: 162 with model FBProphet in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'fbprophet'") in model 162 in generation 0: FBProphet
# Model Number: 163 with model ETS in generation 0 of 10
# Model Number: 164 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 164 in generation 0: VAR
# Model Number: 165 with model MultivariateMotif in generation 0 of 10
# Model Number: 166 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 166 in generation 0: VAR
# Model Number: 167 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 167 in generation 0: ARIMA
# Model Number: 168 with model UnobservedComponents in generation 0 of 10
# Model Number: 169 with model UnivariateMotif in generation 0 of 10
# Model Number: 170 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 170 in generation 0: VAR
# Model Number: 171 with model Theta in generation 0 of 10
# Model Number: 172 with model MultivariateMotif in generation 0 of 10
# Model Number: 173 with model UnobservedComponents in generation 0 of 10
# Model Number: 174 with model WindowRegression in generation 0 of 10
# Model Number: 175 with model SeasonalNaive in generation 0 of 10
# Model Number: 176 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 176 in generation 0: ARDL
# Model Number: 177 with model GLS in generation 0 of 10
# Model Number: 178 with model SectionalMotif in generation 0 of 10
# Model Number: 179 with model ARDL in generation 0 of 10
# Model Number: 180 with model MultivariateMotif in generation 0 of 10
# Model Number: 181 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 181 in generation 0: ARCH
# Model Number: 182 with model SectionalMotif in generation 0 of 10
# Model Number: 183 with model ARIMA in generation 0 of 10
# Model Number: 184 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 184 in generation 0: DatepartRegression
# Model Number: 185 with model ETS in generation 0 of 10
# Model Number: 186 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 186 in generation 0: VECM
# New Generation: 1 of 10
# Model Number: 187 with model WindowRegression in generation 1 of 10
# Model Number: 188 with model MetricMotif in generation 1 of 10
# Model Number: 189 with model AverageValueNaive in generation 1 of 10
# Model Number: 190 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 190 in generation 1: ARDL
# Model Number: 191 with model Theta in generation 1 of 10
# Model Number: 192 with model WindowRegression in generation 1 of 10
# Model Number: 193 with model ETS in generation 1 of 10
# Model Number: 194 with model LastValueNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 194 in generation 1: LastValueNaive
# Model Number: 195 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 195 in generation 1: ARDL
# Model Number: 196 with model MetricMotif in generation 1 of 10
# Model Number: 197 with model Theta in generation 1 of 10
# Model Number: 198 with model SectionalMotif in generation 1 of 10
# Model Number: 199 with model GLM in generation 1 of 10
# Model Number: 200 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 200 in generation 1: UnobservedComponents
# Model Number: 201 with model ARIMA in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 201 in generation 1: ARIMA
# Model Number: 202 with model LastValueNaive in generation 1 of 10
# Model Number: 203 with model DatepartRegression in generation 1 of 10
# Model Number: 204 with model SeasonalNaive in generation 1 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning:
#
# The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Model Number: 205 with model SectionalMotif in generation 1 of 10
# Model Number: 206 with model Theta in generation 1 of 10
# Model Number: 207 with model ConstantNaive in generation 1 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 207 in generation 1: ConstantNaive
# Model Number: 208 with model ConstantNaive in generation 1 of 10
# Model Number: 209 with model UnivariateMotif in generation 1 of 10
# Model Number: 210 with model AverageValueNaive in generation 1 of 10
# Model Number: 211 with model NVAR in generation 1 of 10
# Model Number: 212 with model UnivariateMotif in generation 1 of 10
# Model Number: 213 with model ConstantNaive in generation 1 of 10
# Model Number: 214 with model ETS in generation 1 of 10
# Model Number: 215 with model MetricMotif in generation 1 of 10
# Model Number: 216 with model MetricMotif in generation 1 of 10
# Model Number: 217 with model LastValueNaive in generation 1 of 10
# Model Number: 218 with model ConstantNaive in generation 1 of 10
# Model Number: 219 with model MetricMotif in generation 1 of 10
# Model Number: 220 with model UnivariateRegression in generation 1 of 10
# Model Number: 221 with model SectionalMotif in generation 1 of 10
# Model Number: 222 with model LastValueNaive in generation 1 of 10
# Model Number: 223 with model MetricMotif in generation 1 of 10
# Model Number: 224 with model AverageValueNaive in generation 1 of 10
# Model Number: 225 with model WindowRegression in generation 1 of 10
# Model Number: 226 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 226 in generation 1: UnobservedComponents
# Model Number: 227 with model NVAR in generation 1 of 10
# Model Number: 228 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 228 in generation 1: UnivariateRegression
# Model Number: 229 with model UnivariateMotif in generation 1 of 10
# Model Number: 230 with model SeasonalNaive in generation 1 of 10
# Model Number: 231 with model ARDL in generation 1 of 10
# Model Number: 232 with model Theta in generation 1 of 10
# Model Number: 233 with model MultivariateRegression in generation 1 of 10
# Model Number: 234 with model LastValueNaive in generation 1 of 10
# Model Number: 235 with model ARIMA in generation 1 of 10
# Model Number: 236 with model ARIMA in generation 1 of 10
# Model Number: 237 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 237 in generation 1: DatepartRegression
# Model Number: 238 with model NVAR in generation 1 of 10
# Model Number: 239 with model NVAR in generation 1 of 10
# Model Number: 240 with model UnivariateMotif in generation 1 of 10
# Model Number: 241 with model ConstantNaive in generation 1 of 10
# Model Number: 242 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 242 in generation 1: UnobservedComponents
# Model Number: 243 with model AverageValueNaive in generation 1 of 10
# Model Number: 244 with model ARIMA in generation 1 of 10
# Model Number: 245 with model UnobservedComponents in generation 1 of 10
# Model Number: 246 with model GLS in generation 1 of 10
# Model Number: 247 with model NVAR in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 247 in generation 1: NVAR
# Model Number: 248 with model NVAR in generation 1 of 10
# Model Number: 249 with model GLM in generation 1 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 249 in generation 1: GLM
# Model Number: 250 with model UnobservedComponents in generation 1 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:445: RuntimeWarning:
#
# divide by zero encountered in divide
#
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\family.py:143: RuntimeWarning:
#
# divide by zero encountered in divide
# Model Number: 251 with model MultivariateRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer FastICA failed on fit') in model 251 in generation 1: MultivariateRegression
# Model Number: 252 with model LastValueNaive in generation 1 of 10
# Model Number: 253 with model AverageValueNaive in generation 1 of 10
# Model Number: 254 with model SeasonalNaive in generation 1 of 10
# Model Number: 255 with model ARDL in generation 1 of 10
# Template Eval Error: Exception('Transformer FastICA failed on fit') in model 255 in generation 1: ARDL
# Model Number: 256 with model MetricMotif in generation 1 of 10
# Model Number: 257 with model UnivariateMotif in generation 1 of 10
# Model Number: 258 with model DatepartRegression in generation 1 of 10
# Model Number: 259 with model Theta in generation 1 of 10
# Model Number: 260 with model Theta in generation 1 of 10
# Model Number: 261 with model ETS in generation 1 of 10
# Model Number: 262 with model WindowRegression in generation 1 of 10
# Model Number: 263 with model MultivariateRegression in generation 1 of 10
# Model Number: 264 with model ETS in generation 1 of 10
# Model Number: 265 with model GLS in generation 1 of 10
# Model Number: 266 with model DatepartRegression in generation 1 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 267 with model NVAR in generation 1 of 10
# Model Number: 268 with model Theta in generation 1 of 10
# Model Number: 269 with model AverageValueNaive in generation 1 of 10
# Model Number: 270 with model ConstantNaive in generation 1 of 10
# Model Number: 271 with model UnobservedComponents in generation 1 of 10
# Model Number: 272 with model LastValueNaive in generation 1 of 10
# Model Number: 273 with model LastValueNaive in generation 1 of 10
# Model Number: 274 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 274 in generation 1: UnivariateMotif
# Model Number: 275 with model DatepartRegression in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 275 in generation 1: DatepartRegression
# Model Number: 276 with model ARIMA in generation 1 of 10
# Model Number: 277 with model MultivariateMotif in generation 1 of 10
# Model Number: 278 with model UnobservedComponents in generation 1 of 10
# Model Number: 279 with model ARIMA in generation 1 of 10
# Model Number: 280 with model ETS in generation 1 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 281 with model ARIMA in generation 1 of 10
# Model Number: 282 with model MultivariateMotif in generation 1 of 10
# Model Number: 283 with model GLS in generation 1 of 10
# Model Number: 284 with model UnobservedComponents in generation 1 of 10
# Model Number: 285 with model ETS in generation 1 of 10
# Model Number: 286 with model LastValueNaive in generation 1 of 10
# Model Number: 287 with model ARDL in generation 1 of 10
# Template Eval Error: Exception('Transformer FastICA failed on fit') in model 287 in generation 1: ARDL
# Model Number: 288 with model AverageValueNaive in generation 1 of 10
# Model Number: 289 with model LastValueNaive in generation 1 of 10
# Model Number: 290 with model DatepartRegression in generation 1 of 10
# Model Number: 291 with model MetricMotif in generation 1 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 291 in generation 1: MetricMotif
# Model Number: 292 with model Theta in generation 1 of 10
# Model Number: 293 with model UnivariateRegression in generation 1 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:2412: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4583295347921268.0, tolerance: 83651971356748.52
# Model Number: 294 with model GLS in generation 1 of 10
# Model Number: 295 with model Theta in generation 1 of 10
# Model Number: 296 with model Theta in generation 1 of 10
# Model Number: 297 with model ConstantNaive in generation 1 of 10
# Model Number: 298 with model SectionalMotif in generation 1 of 10
# Model Number: 299 with model ARDL in generation 1 of 10
# Model Number: 300 with model ETS in generation 1 of 10
# Model Number: 301 with model SectionalMotif in generation 1 of 10
# Model Number: 302 with model WindowRegression in generation 1 of 10
# Model Number: 303 with model ETS in generation 1 of 10
# Model Number: 304 with model LastValueNaive in generation 1 of 10
# Model Number: 305 with model Theta in generation 1 of 10
# Model Number: 306 with model SeasonalNaive in generation 1 of 10
# Model Number: 307 with model ARDL in generation 1 of 10
# Model Number: 308 with model GLS in generation 1 of 10
# Model Number: 309 with model AverageValueNaive in generation 1 of 10
# Model Number: 310 with model MetricMotif in generation 1 of 10
# Model Number: 311 with model ARIMA in generation 1 of 10
# New Generation: 2 of 10
# Model Number: 312 with model Theta in generation 2 of 10
# Model Number: 313 with model LastValueNaive in generation 2 of 10
# Model Number: 314 with model DatepartRegression in generation 2 of 10
# Model Number: 315 with model ARIMA in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 315 in generation 2: ARIMA
# Model Number: 316 with model ARDL in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 316 in generation 2: ARDL
# Model Number: 317 with model ARDL in generation 2 of 10
# Model Number: 318 with model AverageValueNaive in generation 2 of 10
# Model Number: 319 with model ARIMA in generation 2 of 10
# Model Number: 320 with model LastValueNaive in generation 2 of 10
# Model Number: 321 with model ARIMA in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 321 in generation 2: ARIMA
# Model Number: 322 with model MultivariateRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 322 in generation 2: MultivariateRegression
# Model Number: 323 with model ARDL in generation 2 of 10
# Model Number: 324 with model WindowRegression in generation 2 of 10
# Model Number: 325 with model ETS in generation 2 of 10
# ETS error ValueError('Can only dampen the trend component')
# ETS failed on Close with ValueError('Can only dampen the trend component')
# Model Number: 326 with model DatepartRegression in generation 2 of 10
# Model Number: 327 with model WindowRegression in generation 2 of 10
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\experimental\enable_hist_gradient_boosting.py:15: UserWarning:
#
# Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
# Model Number: 328 with model UnobservedComponents in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 328 in generation 2: UnobservedComponents
# Model Number: 329 with model ConstantNaive in generation 2 of 10
# Model Number: 330 with model UnivariateMotif in generation 2 of 10
# Model Number: 331 with model Theta in generation 2 of 10
# Model Number: 332 with model ARDL in generation 2 of 10
# Model Number: 333 with model WindowRegression in generation 2 of 10
# Model Number: 334 with model MultivariateMotif in generation 2 of 10
# Model Number: 335 with model SectionalMotif in generation 2 of 10
# Model Number: 336 with model ETS in generation 2 of 10
# Model Number: 337 with model DatepartRegression in generation 2 of 10
# Model Number: 338 with model MultivariateMotif in generation 2 of 10
# Model Number: 339 with model MetricMotif in generation 2 of 10
# Model Number: 340 with model WindowRegression in generation 2 of 10
# Model Number: 341 with model MultivariateRegression in generation 2 of 10
# Model Number: 342 with model MultivariateRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 342 in generation 2: MultivariateRegression
# Model Number: 343 with model NVAR in generation 2 of 10
# ...
# Epoch 29/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.2528
# Epoch 30/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2535
# Epoch 31/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2530
# Epoch 32/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2533
# Epoch 33/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2535
# Epoch 34/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2523
# Epoch 35/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2529
# Epoch 36/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2518
# Epoch 37/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2519
# Epoch 38/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2527
# Epoch 39/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2529
# Epoch 40/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2536
# Epoch 41/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2523
# Epoch 42/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2535
# Epoch 43/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2536
# Epoch 44/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2527
# Epoch 45/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2527
# Epoch 46/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2525
# Epoch 47/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2526
# Epoch 48/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2531
# Epoch 49/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2521
# Epoch 50/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2532
# 1/1 [==============================] - 1s 728ms/step
# 169 - DatepartRegression with avg smape 17.5:
# Model Number: 170 of 188 with model DatepartRegression for Validation 3
# Epoch 1/50
# 21/21 [==============================] - 4s 6ms/step - loss: 0.2577
# Epoch 2/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2564
# Epoch 3/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2544
# Epoch 4/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2561
# Epoch 5/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2535
# Epoch 6/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2553
# Epoch 7/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2544
# Epoch 8/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.2566
# Epoch 9/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2548
# Epoch 10/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2548
# Epoch 11/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2537
# Epoch 12/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2523
# Epoch 13/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2544
# Epoch 14/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2537
# Epoch 15/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2536
# Epoch 16/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2540
# Epoch 17/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2532
# Epoch 18/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2538
# Epoch 19/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2529
# Epoch 20/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2538
# Epoch 21/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2535
# Epoch 22/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2529
# Epoch 23/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2531
# Epoch 24/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2536
# Epoch 25/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2558
# Epoch 26/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2539
# Epoch 27/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2525
# Epoch 28/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2531
# Epoch 29/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2528
# Epoch 30/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2546
# Epoch 31/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2520
# Epoch 32/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2522
# Epoch 33/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2539
# Epoch 34/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2527
# Epoch 35/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2527
# Epoch 36/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2532
# Epoch 37/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2521
# Epoch 38/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2528
# Epoch 39/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2530
# Epoch 40/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2534
# Epoch 41/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2530
# Epoch 42/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2534
# Epoch 43/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2535
# Epoch 44/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2524
# Epoch 45/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2530
# Epoch 46/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2530
# Epoch 47/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2530
# Epoch 48/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2527
# Epoch 49/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2529
# Epoch 50/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.2525
# 1/1 [==============================] - 1s 883ms/step
# 170 - DatepartRegression with avg smape 16.35:
# Model Number: 171 of 188 with model DatepartRegression for Validation 3
# Epoch 1/50
# 21/21 [==============================] - 5s 5ms/step - loss: 0.4161
# Epoch 2/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4164
# Epoch 3/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4146
# Epoch 4/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4141
# Epoch 5/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4158
# Epoch 6/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4145
# Epoch 7/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4143
# Epoch 8/50
# 21/21 [==============================] - 0s 5ms/step - loss: 0.4165
# Epoch 9/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4149
# Epoch 10/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4130
# Epoch 11/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4132
# Epoch 12/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4144
# Epoch 13/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4127
# Epoch 14/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4138
# Epoch 15/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4136
# Epoch 16/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4140
# Epoch 17/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4134
# Epoch 18/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4129
# Epoch 19/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4115
# Epoch 20/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4141
# Epoch 21/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4132
# Epoch 22/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4132
# Epoch 23/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4136
# Epoch 24/50
# 21/21 [==============================] - 0s 10ms/step - loss: 0.4133
# Epoch 25/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4146
# Epoch 26/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4131
# Epoch 27/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4116
# Epoch 28/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4136
# Epoch 29/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4126
# Epoch 30/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4133
# Epoch 31/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4112
# Epoch 32/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4116
# Epoch 33/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4135
# Epoch 34/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4118
# Epoch 35/50
# 21/21 [==============================] - 0s 9ms/step - loss: 0.4123
# Epoch 36/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4129
# Epoch 37/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4114
# Epoch 38/50
# 21/21 [==============================] - 0s 11ms/step - loss: 0.4134
# Epoch 39/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4142
# Epoch 40/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4132
# Epoch 41/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4121
# Epoch 42/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4138
# Epoch 43/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4131
# Epoch 44/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4118
# Epoch 45/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4129
# Epoch 46/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4129
# Epoch 47/50
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4128
# Epoch 48/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4129
# Epoch 49/50
# 21/21 [==============================] - 0s 8ms/step - loss: 0.4124
# Epoch 50/50
# 21/21 [==============================] - 0s 6ms/step - loss: 0.4110
# 1/1 [==============================] - 1s 1s/step
# 171 - DatepartRegression with avg smape 9.1:
# Model Number: 172 of 188 with model UnivariateRegression for Validation 3
# 172 - UnivariateRegression with avg smape 7.16:
# Model Number: 173 of 188 with model UnivariateRegression for Validation 3
# 173 - UnivariateRegression with avg smape 7.04:
# Model Number: 174 of 188 with model UnivariateRegression for Validation 3
# 174 - UnivariateRegression with avg smape 5.4:
# Model Number: 175 of 188 with model GLM for Validation 3
# 175 - GLM with avg smape 6.33:
# Model Number: 176 of 188 with model UnivariateRegression for Validation 3
# 176 - UnivariateRegression with avg smape 3.4:
# Model Number: 177 of 188 with model UnivariateRegression for Validation 3
# 177 - UnivariateRegression with avg smape 3.4:
# Model Number: 178 of 188 with model UnivariateRegression for Validation 3
# 178 - UnivariateRegression with avg smape 2.74:
# Model Number: 179 of 188 with model UnivariateRegression for Validation 3
# 179 - UnivariateRegression with avg smape 3.19:
# Model Number: 180 of 188 with model UnivariateRegression for Validation 3
# 180 - UnivariateRegression with avg smape 3.89:
# Model Number: 181 of 188 with model VAR for Validation 3
# 181 - VAR with avg smape 14.99:
# Model Number: 182 of 188 with model GLM for Validation 3
# 182 - GLM with avg smape 13.45:
# Model Number: 183 of 188 with model GLM for Validation 3
# 183 - GLM with avg smape 16.81:
# Model Number: 184 of 188 with model GLM for Validation 3
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\generalized_linear_model.py:307: DomainWarning:
#
# The InversePower link function does not respect the domain of the Gamma family.
# 184 - GLM with avg smape 26.91:
# Model Number: 185 of 188 with model GLM for Validation 3
# 185 - GLM with avg smape 36.07:
# Model Number: 186 of 188 with model GLM for Validation 3
# 186 - GLM with avg smape 41.21:
# Model Number: 187 of 188 with model GLM for Validation 3
# 187 - GLM with avg smape 41.16:
# Model Number: 188 of 188 with model GLM for Validation 3
# c:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\genmod\families\links.py:198: RuntimeWarning:
#
# overflow encountered in exp
# 188 - GLM with avg smape 54.52:
# Model Number: 1834 with model Ensemble in generation 12 of Ensembles
# Model Number: 1835 with model Ensemble in generation 12 of Ensembles
# Model Number: 1836 with model Ensemble in generation 12 of Ensembles
# Model Number: 1837 with model Ensemble in generation 12 of Ensembles
# Model Number: 1838 with model Ensemble in generation 12 of Ensembles
# Model Number: 1839 with model Ensemble in generation 12 of Ensembles
# Model Number: 1840 with model Ensemble in generation 12 of Ensembles
# Model Number: 1841 with model Ensemble in generation 12 of Ensembles
# Validation Round: 1
# Model Number: 1 of 8 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 0.99:
# Model Number: 2 of 8 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 1.26:
# Model Number: 3 of 8 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 2.05:
# Model Number: 4 of 8 with model Ensemble for Validation 1
# 4 - Ensemble with avg smape 1.89:
# Model Number: 5 of 8 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 1.74:
# Model Number: 6 of 8 with model Ensemble for Validation 1
# 6 - Ensemble with avg smape 1.47:
# Model Number: 7 of 8 with model Ensemble for Validation 1
# 7 - Ensemble with avg smape 1.01:
# Model Number: 8 of 8 with model Ensemble for Validation 1
# 8 - Ensemble with avg smape 1.01:
# Validation Round: 2
# Model Number: 1 of 8 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 4.72:
# Model Number: 2 of 8 with model Ensemble for Validation 2
# 📈 2 - Ensemble with avg smape 4.56:
# Model Number: 3 of 8 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 7.85:
# Model Number: 4 of 8 with model Ensemble for Validation 2
# 4 - Ensemble with avg smape 5.93:
# Model Number: 5 of 8 with model Ensemble for Validation 2
# 5 - Ensemble with avg smape 4.81:
# Model Number: 6 of 8 with model Ensemble for Validation 2
# 6 - Ensemble with avg smape 4.72:
# Model Number: 7 of 8 with model Ensemble for Validation 2
# 7 - Ensemble with avg smape 5.76:
# Model Number: 8 of 8 with model Ensemble for Validation 2
# 8 - Ensemble with avg smape 5.75:
# Validation Round: 3
# Model Number: 1 of 8 with model Ensemble for Validation 3
# 📈 1 - Ensemble with avg smape 3.26:
# Model Number: 2 of 8 with model Ensemble for Validation 3
# 2 - Ensemble with avg smape 4.1:
# Model Number: 3 of 8 with model Ensemble for Validation 3
# 📈 3 - Ensemble with avg smape 1.93:
# Model Number: 4 of 8 with model Ensemble for Validation 3
# 📈 4 - Ensemble with avg smape 1.72:
# Model Number: 5 of 8 with model Ensemble for Validation 3
# 5 - Ensemble with avg smape 2.29:
# Model Number: 6 of 8 with model Ensemble for Validation 3
# 6 - Ensemble with avg smape 3.15:
# Model Number: 7 of 8 with model Ensemble for Validation 3
# 7 - Ensemble with avg smape 2.89:
# Model Number: 8 of 8 with model Ensemble for Validation 3
# 8 - Ensemble with avg smape 2.92:
#                    Close
# 2023-08-26  26096.056313
# 2023-08-27  26021.019796
# 2023-08-28  25964.726661
# 2023-08-29  25901.169950
# 2023-08-30  25837.796703
# 2023-08-31  25774.943968
# 2023-09-01  25758.916751
# 2023-09-02  25717.303361
# 2023-09-03  25649.407317
# 2023-09-04  25665.254239
# 2023-09-05  25598.468951
# 2023-09-06  25533.503300
# 2023-09-07  25599.770374
# 2023-09-08  25603.656765
# 2023-09-09  25563.537709
# 2023-09-10  25523.418654
# 2023-09-11  25483.299598
# 2023-09-12  25443.180542
# 2023-09-13  25403.061487
# 2023-09-14  25362.942431
# 2023-09-15  25322.823375
# 2023-09-16  25282.704319
# 2023-09-17  25242.585264
# 2023-09-18  25202.466208
# 2023-09-19  25162.347152
# 2023-09-20  25122.228097
# 2023-09-21  25082.109041
# 2023-09-22  25041.989985
# 2023-09-23  25001.870930
# 2023-09-24  24961.751874
